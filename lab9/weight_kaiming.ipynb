# %% [markdown]
# CSCI 4852 & 6952: Deep Learning (Spring 2023)
#
# Instructor: Alina Lazar (alazar@ysu.edu)
# GitHub repository:https://github.com/alinutzal/CSCI-xx52-Deep-Learning-
# ---

# %% [markdown]
# # MLP with Dropout

# %% [markdown]
# ## Imports

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
# From local helper files
from helper_evaluation import set_all_seeds, set_deterministic
from helper_train import train_model
from helper_plotting import plot_training_loss, plot_accuracy, show_examples
from helper_dataset import get_dataloaders_mnist

# %% [markdown]
# ## Settings and Dataset

# %%
##########################
### SETTINGS
##########################

RANDOM_SEED = 123
BATCH_SIZE = 256
NUM_HIDDEN_1 = 75
NUM_HIDDEN_2 = 45
NUM_EPOCHS = 50
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
set_all_seeds(RANDOM_SEED)
#set_deterministic()

# %%
##########################
### MNIST DATASET
##########################

train_loader, valid_loader, test_loader = get_dataloaders_mnist(
    batch_size=BATCH_SIZE,
    validation_fraction=0.1)

# Checking the dataset
for images, labels in train_loader:  
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    print('Class labels of 10 examples:', labels[:10])
    break
# Out:
# Image batch dimensions: torch.Size([256, 1, 28, 28])
# Image label dimensions: torch.Size([256])
# Class labels of 10 examples: tensor([4, 5, 8, 9, 9, 4, 9, 9, 3, 9])

# %% [markdown]
# ## Model

# %%
class MultilayerPerceptron(torch.nn.Module):

    def __init__(self, num_features, num_classes, drop_proba, 
                 num_hidden_1, num_hidden_2):
        super().__init__()
        
        self.my_network = torch.nn.Sequential(
            # 1st hidden layer
            torch.nn.Flatten(),
            torch.nn.Linear(num_features, num_hidden_1),
            torch.nn.ReLU(),
            # 2nd hidden layer
            torch.nn.Linear(num_hidden_1, num_hidden_2),
            torch.nn.ReLU(),
            # output layer
            torch.nn.Linear(num_hidden_2, num_classes)
        )

        for m in self.modules():
            if isinstance(m, torch.nn.Linear):
                torch.nn.init.kaiming_uniform_(m.weight, mode='fan_in', nonlinearity='relu')
                if m.bias is not None:
                    m.bias.detach().zero_()
           
    def forward(self, x):
        logits = self.my_network(x)
        return logits

# %%
torch.manual_seed(RANDOM_SEED)
model = MultilayerPerceptron(num_features=28*28,
                             num_hidden_1=NUM_HIDDEN_1,
                             num_hidden_2=NUM_HIDDEN_2,
                             drop_proba=0.5,
                             num_classes=10)
model = model.to(DEVICE)

optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

minibatch_loss_list, train_acc_list, valid_acc_list = train_model(
    model=model,
    num_epochs=NUM_EPOCHS,
    train_loader=train_loader,
    valid_loader=valid_loader,
    test_loader=test_loader,
    optimizer=optimizer,
    device=DEVICE)

plot_training_loss(minibatch_loss_list=minibatch_loss_list,
                   num_epochs=NUM_EPOCHS,
                   iter_per_epoch=len(train_loader),
                   results_dir=None,
                   averaging_iterations=20)
#plt.show()
#plt.figure(figsize=(8,12))
plt.savefig('loss.jpg')
plot_accuracy(train_acc_list=train_acc_list,
              valid_acc_list=valid_acc_list,
              results_dir=None)
plt.ylim([80, 100])
#plt.show()
plt.savefig('train_valacc.jpg')
# Out:
# Epoch: 001/050 | Batch 0000/0210 | Loss: 2.6304
# Epoch: 001/050 | Batch 0050/0210 | Loss: 0.6442
# Epoch: 001/050 | Batch 0100/0210 | Loss: 0.3850
# Epoch: 001/050 | Batch 0150/0210 | Loss: 0.3311
# Epoch: 001/050 | Batch 0200/0210 | Loss: 0.2582
# Epoch: 001/050 | Train: 90.85% | Validation: 92.55%
# Time elapsed: 0.16 min
# Epoch: 002/050 | Batch 0000/0210 | Loss: 0.2813
# Epoch: 002/050 | Batch 0050/0210 | Loss: 0.3330
# Epoch: 002/050 | Batch 0100/0210 | Loss: 0.2894
# Epoch: 002/050 | Batch 0150/0210 | Loss: 0.2680
# Epoch: 002/050 | Batch 0200/0210 | Loss: 0.2470
# Epoch: 002/050 | Train: 92.97% | Validation: 94.53%
# Time elapsed: 0.31 min
# Epoch: 003/050 | Batch 0000/0210 | Loss: 0.2368
# Epoch: 003/050 | Batch 0050/0210 | Loss: 0.2123
# Epoch: 003/050 | Batch 0100/0210 | Loss: 0.2535
# Epoch: 003/050 | Batch 0150/0210 | Loss: 0.2411
# Epoch: 003/050 | Batch 0200/0210 | Loss: 0.2201
# Epoch: 003/050 | Train: 93.89% | Validation: 94.80%
# Time elapsed: 0.46 min
# Epoch: 004/050 | Batch 0000/0210 | Loss: 0.2237
# Epoch: 004/050 | Batch 0050/0210 | Loss: 0.2355
# Epoch: 004/050 | Batch 0100/0210 | Loss: 0.1409
# Epoch: 004/050 | Batch 0150/0210 | Loss: 0.2170
# Epoch: 004/050 | Batch 0200/0210 | Loss: 0.2434
# Epoch: 004/050 | Train: 94.83% | Validation: 95.87%
# Time elapsed: 0.61 min
# Epoch: 005/050 | Batch 0000/0210 | Loss: 0.2008
# Epoch: 005/050 | Batch 0050/0210 | Loss: 0.2022
# Epoch: 005/050 | Batch 0100/0210 | Loss: 0.1998
# Epoch: 005/050 | Batch 0150/0210 | Loss: 0.1204
# Epoch: 005/050 | Batch 0200/0210 | Loss: 0.1732
# Epoch: 005/050 | Train: 95.44% | Validation: 96.33%
# Time elapsed: 0.76 min
# Epoch: 006/050 | Batch 0000/0210 | Loss: 0.1298
# Epoch: 006/050 | Batch 0050/0210 | Loss: 0.1214
# Epoch: 006/050 | Batch 0100/0210 | Loss: 0.1114
# Epoch: 006/050 | Batch 0150/0210 | Loss: 0.1164
# Epoch: 006/050 | Batch 0200/0210 | Loss: 0.1380
# Epoch: 006/050 | Train: 95.96% | Validation: 96.58%
# Time elapsed: 0.92 min
# Epoch: 007/050 | Batch 0000/0210 | Loss: 0.1113
# Epoch: 007/050 | Batch 0050/0210 | Loss: 0.1341
# Epoch: 007/050 | Batch 0100/0210 | Loss: 0.1804
# Epoch: 007/050 | Batch 0150/0210 | Loss: 0.1256
# Epoch: 007/050 | Batch 0200/0210 | Loss: 0.0729
# Epoch: 007/050 | Train: 96.26% | Validation: 96.70%
# Time elapsed: 1.07 min
# Epoch: 008/050 | Batch 0000/0210 | Loss: 0.0712
# Epoch: 008/050 | Batch 0050/0210 | Loss: 0.1396
# Epoch: 008/050 | Batch 0100/0210 | Loss: 0.1152
# Epoch: 008/050 | Batch 0150/0210 | Loss: 0.1200
# Epoch: 008/050 | Batch 0200/0210 | Loss: 0.1695
# Epoch: 008/050 | Train: 96.64% | Validation: 96.80%
# Time elapsed: 1.22 min
# Epoch: 009/050 | Batch 0000/0210 | Loss: 0.1394
# Epoch: 009/050 | Batch 0050/0210 | Loss: 0.0786
# Epoch: 009/050 | Batch 0100/0210 | Loss: 0.1269
# Epoch: 009/050 | Batch 0150/0210 | Loss: 0.1358
# Epoch: 009/050 | Batch 0200/0210 | Loss: 0.1562
# Epoch: 009/050 | Train: 96.95% | Validation: 97.00%
# Time elapsed: 1.37 min
# Epoch: 010/050 | Batch 0000/0210 | Loss: 0.0931
# Epoch: 010/050 | Batch 0050/0210 | Loss: 0.0636
# Epoch: 010/050 | Batch 0100/0210 | Loss: 0.0795
# Epoch: 010/050 | Batch 0150/0210 | Loss: 0.1358
# Epoch: 010/050 | Batch 0200/0210 | Loss: 0.1292
# Epoch: 010/050 | Train: 97.22% | Validation: 97.18%
# Time elapsed: 1.53 min
# Epoch: 011/050 | Batch 0000/0210 | Loss: 0.0824
# Epoch: 011/050 | Batch 0050/0210 | Loss: 0.1110
# Epoch: 011/050 | Batch 0100/0210 | Loss: 0.1137
# Epoch: 011/050 | Batch 0150/0210 | Loss: 0.1046
# Epoch: 011/050 | Batch 0200/0210 | Loss: 0.0830
# Epoch: 011/050 | Train: 97.49% | Validation: 97.32%
# Time elapsed: 1.68 min
# Epoch: 012/050 | Batch 0000/0210 | Loss: 0.0730
# Epoch: 012/050 | Batch 0050/0210 | Loss: 0.1131
# Epoch: 012/050 | Batch 0100/0210 | Loss: 0.0894
# Epoch: 012/050 | Batch 0150/0210 | Loss: 0.0565
# Epoch: 012/050 | Batch 0200/0210 | Loss: 0.1155
# Epoch: 012/050 | Train: 97.55% | Validation: 97.33%
# Time elapsed: 1.83 min
# Epoch: 013/050 | Batch 0000/0210 | Loss: 0.1004
# Epoch: 013/050 | Batch 0050/0210 | Loss: 0.1083
# Epoch: 013/050 | Batch 0100/0210 | Loss: 0.1198
# Epoch: 013/050 | Batch 0150/0210 | Loss: 0.1080
# Epoch: 013/050 | Batch 0200/0210 | Loss: 0.0990
# Epoch: 013/050 | Train: 97.67% | Validation: 97.30%
# Time elapsed: 1.98 min
# Epoch: 014/050 | Batch 0000/0210 | Loss: 0.1192
# Epoch: 014/050 | Batch 0050/0210 | Loss: 0.0582
# Epoch: 014/050 | Batch 0100/0210 | Loss: 0.1007
# Epoch: 014/050 | Batch 0150/0210 | Loss: 0.0788
# Epoch: 014/050 | Batch 0200/0210 | Loss: 0.0610
# Epoch: 014/050 | Train: 97.96% | Validation: 97.40%
# Time elapsed: 2.13 min
# Epoch: 015/050 | Batch 0000/0210 | Loss: 0.0548
# Epoch: 015/050 | Batch 0050/0210 | Loss: 0.0721
# Epoch: 036/050 | Train: 99.47% | Validation: 97.80%
# Time elapsed: 5.41 min
# Epoch: 037/050 | Batch 0000/0210 | Loss: 0.0160
# Epoch: 037/050 | Batch 0050/0210 | Loss: 0.0142
# Epoch: 037/050 | Batch 0100/0210 | Loss: 0.0218
# Epoch: 037/050 | Batch 0150/0210 | Loss: 0.0216
# Epoch: 037/050 | Batch 0200/0210 | Loss: 0.0603
# Epoch: 037/050 | Train: 99.55% | Validation: 97.83%
# Time elapsed: 5.55 min
# Epoch: 038/050 | Batch 0000/0210 | Loss: 0.0181
# Epoch: 038/050 | Batch 0050/0210 | Loss: 0.0277
# Epoch: 038/050 | Batch 0100/0210 | Loss: 0.0276
# Epoch: 038/050 | Batch 0150/0210 | Loss: 0.0354
# Epoch: 038/050 | Batch 0200/0210 | Loss: 0.0470
# Epoch: 038/050 | Train: 99.59% | Validation: 97.97%
# Time elapsed: 5.70 min
# Epoch: 039/050 | Batch 0000/0210 | Loss: 0.0188
# Epoch: 039/050 | Batch 0050/0210 | Loss: 0.0282
# Epoch: 039/050 | Batch 0100/0210 | Loss: 0.0110
# Epoch: 039/050 | Batch 0150/0210 | Loss: 0.0459
# Epoch: 039/050 | Batch 0200/0210 | Loss: 0.0161
# Epoch: 039/050 | Train: 99.64% | Validation: 97.82%
# Time elapsed: 5.84 min
# Epoch: 040/050 | Batch 0000/0210 | Loss: 0.0332
# Epoch: 040/050 | Batch 0050/0210 | Loss: 0.0244
# Epoch: 040/050 | Batch 0100/0210 | Loss: 0.0321
# Epoch: 040/050 | Batch 0150/0210 | Loss: 0.0174
# Epoch: 040/050 | Batch 0200/0210 | Loss: 0.0177
# Epoch: 040/050 | Train: 99.65% | Validation: 97.73%
# Time elapsed: 5.99 min
# Epoch: 041/050 | Batch 0000/0210 | Loss: 0.0065
# Epoch: 041/050 | Batch 0050/0210 | Loss: 0.0205
# Epoch: 041/050 | Batch 0100/0210 | Loss: 0.0150
# Epoch: 041/050 | Batch 0150/0210 | Loss: 0.0217
# Epoch: 041/050 | Batch 0200/0210 | Loss: 0.0241
# Epoch: 041/050 | Train: 99.62% | Validation: 97.83%
# Time elapsed: 6.13 min
# Epoch: 042/050 | Batch 0000/0210 | Loss: 0.0100
# Epoch: 042/050 | Batch 0050/0210 | Loss: 0.0244
# Epoch: 042/050 | Batch 0100/0210 | Loss: 0.0125
# Epoch: 042/050 | Batch 0150/0210 | Loss: 0.0120
# Epoch: 042/050 | Batch 0200/0210 | Loss: 0.0125
# Epoch: 042/050 | Train: 99.68% | Validation: 97.75%
# Time elapsed: 6.28 min
# Epoch: 043/050 | Batch 0000/0210 | Loss: 0.0150
# Epoch: 043/050 | Batch 0050/0210 | Loss: 0.0218
# Epoch: 043/050 | Batch 0100/0210 | Loss: 0.0371
# Epoch: 043/050 | Batch 0150/0210 | Loss: 0.0126
# Epoch: 043/050 | Batch 0200/0210 | Loss: 0.0207
# Epoch: 043/050 | Train: 99.69% | Validation: 97.85%
# Time elapsed: 6.43 min
# Epoch: 044/050 | Batch 0000/0210 | Loss: 0.0129
# Epoch: 044/050 | Batch 0050/0210 | Loss: 0.0132
# Epoch: 044/050 | Batch 0100/0210 | Loss: 0.0143
# Epoch: 044/050 | Batch 0150/0210 | Loss: 0.0167
# Epoch: 044/050 | Batch 0200/0210 | Loss: 0.0201
# Epoch: 044/050 | Train: 99.69% | Validation: 97.95%
# Time elapsed: 6.57 min
# Epoch: 045/050 | Batch 0000/0210 | Loss: 0.0105
# Epoch: 045/050 | Batch 0050/0210 | Loss: 0.0074
# Epoch: 045/050 | Batch 0100/0210 | Loss: 0.0140
# Epoch: 045/050 | Batch 0150/0210 | Loss: 0.0228
# Epoch: 045/050 | Batch 0200/0210 | Loss: 0.0090
# Epoch: 045/050 | Train: 99.76% | Validation: 97.85%
# Time elapsed: 6.72 min
# Epoch: 046/050 | Batch 0000/0210 | Loss: 0.0080
# Epoch: 046/050 | Batch 0050/0210 | Loss: 0.0162
# Epoch: 046/050 | Batch 0100/0210 | Loss: 0.0172
# Epoch: 046/050 | Batch 0150/0210 | Loss: 0.0052
# Epoch: 046/050 | Batch 0200/0210 | Loss: 0.0178
# Epoch: 046/050 | Train: 99.74% | Validation: 97.67%
# Time elapsed: 6.86 min
# Epoch: 047/050 | Batch 0000/0210 | Loss: 0.0190
# Epoch: 047/050 | Batch 0050/0210 | Loss: 0.0251
# Epoch: 047/050 | Batch 0100/0210 | Loss: 0.0100
# Epoch: 047/050 | Batch 0150/0210 | Loss: 0.0110
# Epoch: 047/050 | Batch 0200/0210 | Loss: 0.0215
# Epoch: 047/050 | Train: 99.82% | Validation: 97.77%
# Time elapsed: 7.01 min
# Epoch: 048/050 | Batch 0000/0210 | Loss: 0.0081
# Epoch: 048/050 | Batch 0050/0210 | Loss: 0.0060
# Epoch: 048/050 | Batch 0100/0210 | Loss: 0.0142
# Epoch: 048/050 | Batch 0150/0210 | Loss: 0.0202
# Epoch: 048/050 | Batch 0200/0210 | Loss: 0.0133
# Epoch: 048/050 | Train: 99.87% | Validation: 97.77%
# Time elapsed: 7.15 min
# Epoch: 049/050 | Batch 0000/0210 | Loss: 0.0080
# Epoch: 049/050 | Batch 0050/0210 | Loss: 0.0077
# Epoch: 049/050 | Batch 0100/0210 | Loss: 0.0113
# Epoch: 049/050 | Batch 0150/0210 | Loss: 0.0100
# Epoch: 049/050 | Batch 0200/0210 | Loss: 0.0091
# Epoch: 049/050 | Train: 99.85% | Validation: 97.77%
# Time elapsed: 7.30 min
# Epoch: 050/050 | Batch 0000/0210 | Loss: 0.0082
# Epoch: 050/050 | Batch 0050/0210 | Loss: 0.0112
# Epoch: 050/050 | Batch 0100/0210 | Loss: 0.0097
# Epoch: 050/050 | Batch 0150/0210 | Loss: 0.0109
# Epoch: 050/050 | Batch 0200/0210 | Loss: 0.0097
# Epoch: 050/050 | Train: 99.86% | Validation: 97.87%
# Time elapsed: 7.44 min
# Total Training Time: 7.44 min
# Test accuracy 97.61%
